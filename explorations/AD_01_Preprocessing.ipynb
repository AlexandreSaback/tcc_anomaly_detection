# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os
from os.path import join
import re

# %% [markdown]
# # Funções Úteis

# %%
def match_file_names(
    pattern: str,
    path: str):

    matched_files = []

    for root, _, files in os.walk(path):
        for file in files:
            if file.lower().endswith(".csv") and pattern.search(file):
                matched_files.append(os.path.join(root, file))

    return matched_files

# %%
def read_files(
    file_names: list[str],
    encoding: str = "utf8",
    delimiter: str = ","):

    df_list = []
    for file_name in file_names:

        with open(file_name, "r", encoding="latin-1") as file:
            lines = file.readlines()
        
        header_index = next(i for i, line in enumerate(lines) if line.startswith("Data"))

        try:
            df = pd.read_csv(
                file_name, 
                skiprows=header_index,
                encoding=encoding, 
                delimiter=delimiter)
            df = df.drop(columns=["Unnamed: 19"])
            df_list.append(df)
        except Exception as e:
            print(f"Exception {e} on {file_name}")

        
    return df_list

# %%
def replace_comma(value):

    if isinstance(value, str): 
        return pd.to_numeric(value.replace(",", "."), errors='coerce') 
    
    return value

# %% [markdown]
# # Coleta de Dados

# %%
MODULE_PATH = Path().absolute().parent
DATA_PATH = join(MODULE_PATH, "sources")

# %%
pattern = re.compile(r"BELO[\s_\-]?HORIZONTE|PAMPULHA", re.IGNORECASE)
matched_files = match_file_names(pattern=pattern, path=DATA_PATH)

# %%
df_list = read_files(file_names=matched_files, encoding="latin-1", delimiter=";")

# %% [markdown]
# # Pré-processamento

# %%
for df in df_list:
    df["Hora UTC"] = df["Hora UTC"].str.replace(" UTC", "")
    df["Datetime"] = pd.to_datetime(df["Data"] + " " + df["Hora UTC"], format="%Y/%m/%d %H%M")

    df.rename(columns={"RADIACAO GLOBAL (KJ/m²)": "RADIACAO GLOBAL (Kj/m²)"}, inplace=True)

    for col in [col for col in df.columns if col not in ["Data", "Hora UTC", "Datetime"]]:
        df[col] = df[col].apply(replace_comma)

# %%
df_years_dict = {}

i = 0
for first_file_name, first_df in zip(matched_files, df_list):
    first_file_year = first_file_name.split("\\")[-2]

    common_year_df_list = [first_df]
    for second_file_name, second_df in zip(matched_files[i+1:], df_list[i+1:]):
        second_file_year = second_file_name.split("\\")[-2]

        if first_file_year == second_file_year:
            common_year_df_list.append(second_df)

    if first_file_year not in df_years_dict.keys():
        df_years_dict[first_file_year] = common_year_df_list
    i+=1

# %%
combined_df_by_year_dict = {}
for year, year_df_list in df_years_dict.items():

    year_df_list = [df.set_index("Datetime").asfreq("h").reset_index() for df in year_df_list]

    combined_df = pd.concat(year_df_list)
    combined_df = combined_df.drop(columns=["Data", "Hora UTC"])
    result = combined_df.groupby("Datetime").mean().reset_index()

    combined_df_by_year_dict[year] = result

# %%
complete_df = pd.concat(list(combined_df_by_year_dict.values())).set_index("Datetime").asfreq("h")

# %%
complete_df
# Out:
#                      PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# Datetime
# 2019-01-01 00:00:00                               0.0
# 2019-01-01 01:00:00                               0.0
# 2019-01-01 02:00:00                               0.0
# 2019-01-01 03:00:00                               0.0
# 2019-01-01 04:00:00                               0.0
# ...                                               ...
# 2023-12-31 19:00:00                               0.0
# 2023-12-31 20:00:00                               0.1
# 2023-12-31 21:00:00                               3.4
# 2023-12-31 22:00:00                              10.5
# 2023-12-31 23:00:00                               0.1
#
#                      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# Datetime
# 2019-01-01 00:00:00                                             899.80
# 2019-01-01 01:00:00                                             900.35
# 2019-01-01 02:00:00                                             900.45
# 2019-01-01 03:00:00                                             899.75
# 2019-01-01 04:00:00                                             899.80
# ...                                                                ...
# 2023-12-31 19:00:00                                             897.70
# 2023-12-31 20:00:00                                             897.45
# 2023-12-31 21:00:00                                             897.95
# 2023-12-31 22:00:00                                             898.30
# 2023-12-31 23:00:00                                             899.10
#
#                      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# Datetime
# 2019-01-01 00:00:00                                           899.80
# 2019-01-01 01:00:00                                           900.35
# 2019-01-01 02:00:00                                           900.55
# 2019-01-01 03:00:00                                           900.45
# 2019-01-01 04:00:00                                           899.85
# ...                                                              ...
# 2023-12-31 19:00:00                                           898.30
# 2023-12-31 20:00:00                                           897.70
# 2023-12-31 21:00:00                                           897.95
# 2023-12-31 22:00:00                                           898.40
# 2023-12-31 23:00:00                                           899.10
#
#                      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# Datetime
# 2019-01-01 00:00:00                                            899.15
# 2019-01-01 01:00:00                                            899.80
# 2019-01-01 02:00:00                                            900.30
# 2019-01-01 03:00:00                                            899.75
# 2019-01-01 04:00:00                                            899.55
# ...                                                               ...
# 2023-12-31 19:00:00                                            897.50
# 2023-12-31 20:00:00                                            897.40
# 2023-12-31 21:00:00                                            897.35
# 2023-12-31 22:00:00                                            897.90
# 2023-12-31 23:00:00                                            898.25
#
#                      RADIACAO GLOBAL (Kj/m²)  \
# Datetime
# 2019-01-01 00:00:00                      NaN
# 2019-01-01 01:00:00                      NaN
# 2019-01-01 02:00:00                      NaN
# 2019-01-01 03:00:00                      NaN
# 2019-01-01 04:00:00                      NaN
# ...                                      ...
# 2023-12-31 19:00:00                  1551.45
# 2023-12-31 20:00:00                   301.15
# 2023-12-31 21:00:00                    49.85
# 2023-12-31 22:00:00                     9.75
# 2023-12-31 23:00:00                     0.00
#
#                      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# Datetime
# 2019-01-01 00:00:00                                         20.20
# 2019-01-01 01:00:00                                         19.85
# 2019-01-01 02:00:00                                         19.65
# 2019-01-01 03:00:00                                         19.50
# 2019-01-01 04:00:00                                         19.45
# ...                                                           ...
# 2023-12-31 19:00:00                                         24.55
# 2023-12-31 20:00:00                                         23.00
# 2023-12-31 21:00:00                                         20.90
# 2023-12-31 22:00:00                                         20.30
# 2023-12-31 23:00:00                                         20.25
#
#                      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# Datetime
# 2019-01-01 00:00:00                                 19.10
# 2019-01-01 01:00:00                                 18.50
# 2019-01-01 02:00:00                                 18.30
# 2019-01-01 03:00:00                                 17.90
# 2019-01-01 04:00:00                                 18.10
# ...                                                   ...
# 2023-12-31 19:00:00                                 18.75
# 2023-12-31 20:00:00                                 18.55
# 2023-12-31 21:00:00                                 18.80
# 2023-12-31 22:00:00                                 18.75
# 2023-12-31 23:00:00                                 18.65
#
#                      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# Datetime
# 2019-01-01 00:00:00                                       20.85
# 2019-01-01 01:00:00                                       20.25
# 2019-01-01 02:00:00                                       19.90
# 2019-01-01 03:00:00                                       19.75
# 2019-01-01 04:00:00                                       19.70
# ...                                                         ...
# 2023-12-31 19:00:00                                       27.90
# 2023-12-31 20:00:00                                       24.70
# 2023-12-31 21:00:00                                       23.05
# 2023-12-31 22:00:00                                       20.90
# 2023-12-31 23:00:00                                       20.50
#
#                      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# Datetime
# 2019-01-01 00:00:00                                       19.60
# 2019-01-01 01:00:00                                       19.75
# 2019-01-01 02:00:00                                       19.60
# 2019-01-01 03:00:00                                       19.35
# 2019-01-01 04:00:00                                       19.05
# ...                                                         ...
# 2023-12-31 19:00:00                                       24.45
# 2023-12-31 20:00:00                                       22.95
# 2023-12-31 21:00:00                                       20.90
# 2023-12-31 22:00:00                                       20.15
# 2023-12-31 23:00:00                                       20.10
#
#                      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# Datetime
# 2019-01-01 00:00:00                                             19.10
# 2019-01-01 01:00:00                                             19.00
# 2019-01-01 02:00:00                                             18.50
# 2019-01-01 03:00:00                                             18.30
# 2019-01-01 04:00:00                                             18.20
# ...                                                               ...
# 2023-12-31 19:00:00                                             19.80
# 2023-12-31 20:00:00                                             18.90
# 2023-12-31 21:00:00                                             19.05
# 2023-12-31 22:00:00                                             18.95
# 2023-12-31 23:00:00                                             18.95
#
#                      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# Datetime
# 2019-01-01 00:00:00                                             17.60
# 2019-01-01 01:00:00                                             18.40
# 2019-01-01 02:00:00                                             18.20
# 2019-01-01 03:00:00                                             17.90
# 2019-01-01 04:00:00                                             17.60
# ...                                                               ...
# 2023-12-31 19:00:00                                             18.00
# 2023-12-31 20:00:00                                             18.00
# 2023-12-31 21:00:00                                             18.45
# 2023-12-31 22:00:00                                             18.45
# 2023-12-31 23:00:00                                             18.55
#
#                      UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# Datetime
# 2019-01-01 00:00:00                                      88.0
# 2019-01-01 01:00:00                                      86.0
# 2019-01-01 02:00:00                                      86.0
# 2019-01-01 03:00:00                                      87.0
# 2019-01-01 04:00:00                                      89.0
# ...                                                       ...
# 2023-12-31 19:00:00                                      70.0
# 2023-12-31 20:00:00                                      77.0
# 2023-12-31 21:00:00                                      88.0
# 2023-12-31 22:00:00                                      90.5
# 2023-12-31 23:00:00                                      91.0
#
#                      UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# Datetime
# 2019-01-01 00:00:00                                      81.0
# 2019-01-01 01:00:00                                      84.0
# 2019-01-01 02:00:00                                      85.0
# 2019-01-01 03:00:00                                      85.0
# 2019-01-01 04:00:00                                      86.0
# ...                                                       ...
# 2023-12-31 19:00:00                                      59.0
# 2023-12-31 20:00:00                                      68.0
# 2023-12-31 21:00:00                                      76.5
# 2023-12-31 22:00:00                                      88.0
# 2023-12-31 23:00:00                                      90.5
#
#                      UMIDADE RELATIVA DO AR, HORARIA (%)  \
# Datetime
# 2019-01-01 00:00:00                                 86.0
# 2019-01-01 01:00:00                                 85.0
# 2019-01-01 02:00:00                                 86.0
# 2019-01-01 03:00:00                                 86.0
# 2019-01-01 04:00:00                                 88.0
# ...                                                  ...
# 2023-12-31 19:00:00                                 70.0
# 2023-12-31 20:00:00                                 76.5
# 2023-12-31 21:00:00                                 88.0
# 2023-12-31 22:00:00                                 90.5
# 2023-12-31 23:00:00                                 91.0
#
#                      VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# Datetime
# 2019-01-01 00:00:00                                  95.0
# 2019-01-01 01:00:00                                 105.0
# 2019-01-01 02:00:00                                 104.0
# 2019-01-01 03:00:00                                 101.0
# 2019-01-01 04:00:00                                  84.5
# ...                                                   ...
# 2023-12-31 19:00:00                                  92.5
# 2023-12-31 20:00:00                                 110.0
# 2023-12-31 21:00:00                                 140.5
# 2023-12-31 22:00:00                                 131.5
# 2023-12-31 23:00:00                                 117.0
#
#                      VENTO, RAJADA MAXIMA (m/s)  \
# Datetime
# 2019-01-01 00:00:00                        4.70
# 2019-01-01 01:00:00                        5.40
# 2019-01-01 02:00:00                        5.45
# 2019-01-01 03:00:00                        4.10
# 2019-01-01 04:00:00                        3.95
# ...                                         ...
# 2023-12-31 19:00:00                        9.05
# 2023-12-31 20:00:00                        8.20
# 2023-12-31 21:00:00                       10.70
# 2023-12-31 22:00:00                        9.90
# 2023-12-31 23:00:00                        7.95
#
#                      VENTO, VELOCIDADE HORARIA (m/s)
# Datetime
# 2019-01-01 00:00:00                             2.85
# 2019-01-01 01:00:00                             3.40
# 2019-01-01 02:00:00                             2.25
# 2019-01-01 03:00:00                             1.55
# 2019-01-01 04:00:00                             1.55
# ...                                              ...
# 2023-12-31 19:00:00                             3.70
# 2023-12-31 20:00:00                             4.80
# 2023-12-31 21:00:00                             5.50
# 2023-12-31 22:00:00                             4.65
# 2023-12-31 23:00:00                             5.20
#
# [43824 rows x 17 columns]
